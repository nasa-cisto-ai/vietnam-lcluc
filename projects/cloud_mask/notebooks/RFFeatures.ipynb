# %%
import joblib
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn.tree import export_text

# %%
output_pkl = '/Users/jacaraba/Desktop/development/ilab/vietnam-lcluc/data/cloud_training_4band_BGRNIR1.pkl'
rf = joblib.load(output_pkl)

# %%
fig = plt.figure(figsize=(15, 10))
plot_tree(rf.estimators_[0], 
          feature_names=['b','g','r','nir1'],
          class_names=['cloud', 'not cloud'], 
          filled=True, impurity=True, 
          rounded=True)
plt.show()

# %%
fig = plt.figure(figsize=(15, 10))
plot_tree(rf.estimators_[0], 
          feature_names=['b','g','r','nir1'],
          class_names=['cloud', 'not cloud'], 
          filled=True, impurity=True, 
          rounded=True)
plt.show()

# %%
from sklearn.datasets import load_wine
from sklearn.ensemble import RandomForestClassifier
from dtreeviz.trees import dtreeviz

viz = dtreeviz(rf.estimators_[19], X, y,
               target_name="wine category",
              feature_names=['b','g','r','nir1'],
              class_names=['cloud', 'not cloud'],
               title="100th decision tree - Wine data")

viz.save("decision_tree_wine.svg")
